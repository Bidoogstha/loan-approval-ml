# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import missingno as msno

# %%
pd.set_option("display.max_columns", 200)

# %%
df_raw = pd.read_csv(
    "../data/raw/accepted_2007_to_2018Q4.csv",
    low_memory=False,
    nrows=100_000,
)
print(df_raw.shape)
df_raw.head()
# Out:
# (100000, 151)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
# ...

# %%
print(f"Total columns: {len(df_raw.columns)}")
# Out:
# Total columns: 151

# %%
print(df_raw.columns.tolist())
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq
# ...

# %%
print(df_raw["loan_status"].value_counts())
# Out:
# loan_status
# Fully Paid            70288
# Charged Off           17603
# Current               11402
# Late (31-120 days)      441
# In Grace Period         199
# Late (16-30 days)        66
# Default                   1
# Name: count, dtype: int64

# %%
missing_pct = (df_raw.isnull().sum() / len(df_raw) * 100).sort_values(ascending=False)

# %%
print(missing_pct[missing_pct > 0].head(40))
# Out:
# sec_app_open_act_il                           100.000
# member_id                                     100.000
# revol_bal_joint                               100.000
# sec_app_fico_range_low                        100.000
# sec_app_fico_range_high                       100.000
# sec_app_earliest_cr_line                      100.000
# sec_app_inq_last_6mths                        100.000
# sec_app_mort_acc                              100.000
# sec_app_open_acc                              100.000
# sec_app_revol_util                            100.000
# sec_app_num_rev_accts                         100.000
# sec_app_chargeoff_within_12_mths              100.000
# sec_app_collections_12_mths_ex_med            100.000
# sec_app_mths_since_last_major_derog           100.000
# desc                                           99.993
# dti_joint                                      99.500
# verification_status_joint                      99.498
# ...

# %%
sample = df_raw.sample(5000, random_state=42)

# %%
msno.matrix(sample)
# Out:
# <Axes: >

# %%
plt.show()

# %%
df_raw[["loan_amnt", "annual_inc", "dti", "fico_range_low", "int_rate"]].describe()
# Out:
#            loan_amnt    annual_inc           dti  fico_range_low  \
# count  100000.000000  1.000000e+05  99998.000000   100000.000000
# mean    15055.861000  7.837135e+04     19.250957      694.592800
# std      8641.837441  8.929612e+04      9.627229       30.826355
# min      1000.000000  0.000000e+00      0.000000      660.000000
# 25%      8000.000000  4.760000e+04     12.570000      670.000000
# 50%     13875.000000  6.500000e+04     18.700000      685.000000
# 75%     20000.000000  9.400000e+04     25.530000      710.000000
# max     35000.000000  9.000000e+06    999.000000      845.000000
#
#             int_rate
# count  100000.000000
# mean       12.200478
# std         4.137499
# min         5.320000
# 25%         9.170000
# 50%        11.990000
# 75%        14.480000
# max        28.990000

# %%
df_clean = df_raw[df_raw["loan_status"].isin(["Fully Paid", "Charged Off"])].copy()

# %%
df_clean["defaulted"] = (df_clean["loan_status"] == "Charged Off").astype(int)

# %%
print(f"Default rate: {df_clean['defaulted'].mean():.1%}")
# Out:
# Default rate: 20.0%

# %%
print(df_clean.groupby("defaulted")[["loan_amnt", "annual_inc", "dti", "fico_range_low"]].mean())
# Out:
#               loan_amnt    annual_inc        dti  fico_range_low
# defaulted
# 0          14065.021768  79370.107782  18.470638      696.614145
# 1          15618.175879  70957.425921  21.051428      686.147248
